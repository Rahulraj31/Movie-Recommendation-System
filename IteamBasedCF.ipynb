# %% [markdown]
# # Item - Based Collaborative Filtering
# Let us start by importing the movie lense dataset

# %%
import pandas as pd
import numpy as np

# %%
r_cols=['user_id','movie_id','rating']
ratings =pd.read_csv('ml-100k/u.data',sep='\t',names=r_cols, 
                   usecols=range(3))  #selects 3 columns with index 0 1 2 
m_cols = ['movie_id','title']
movies=pd.read_csv('ml-100k/u.item',sep='|',names=m_cols, 
                   usecols=range(2))
ratings=pd.merge(movies,ratings)

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %% [markdown]
# Now we will make pivot table

# %%
userRating=ratings.pivot_table(index=['user_id'],columns='title',values='rating')
userRating.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
corrMatrix= userRating.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
corrMatrix= userRating.corr(method="pearson", min_periods=110)
#finds corr between movies rated by 100 people min.
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        NaN                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %% [markdown]
# correlation of a movie with themselfes is also NaN if they are rated by less than 100 people

# %%
title = ["Empire Strikes Back, The (1980)","Gone with the Wind (1939)",                                    
"Star Wars (1977)","Adventures of Priscilla, Queen of the Desert, The (1994)"]
rate=[5,1,5,2]
myRatings= pd.Series(data=rate,index=title)
myRatings
# Out:
# Empire Strikes Back, The (1980)                             5
# Gone with the Wind (1939)                                   1
# Star Wars (1977)                                            5
# Adventures of Priscilla, Queen of the Desert, The (1994)    2
# dtype: int64

# %%
simCandidates=pd.Series()
for i in range(0,len(myRatings.index)):
    print(f"Adding sims for {myRatings.index[i]}-")
    
    # retreive similar movies to this one that i rated 
    sims= corrMatrix[myRatings.index[i]].dropna()
    
    #now Scale its similarity by how weill i liked it` 
    sims=sims.map(lambda x:x*myRatings[i]) #multiply our rating with genral ratings of similar movied
    
    #Add the scores to the list  of similarity candidates
    simCandidates =simCandidates.append(sims)
    
print("Sorting..........")
simCandidates.sort_values(inplace=True, ascending = False)
print(simCandidates.head(10))
# Out:
# Adding sims for Empire Strikes Back, The (1980)-
# Adding sims for Gone with the Wind (1939)-
# Adding sims for Star Wars (1977)-
# Adding sims for Adventures of Priscilla, Queen of the Desert, The (1994)-
# Sorting..........
# Star Wars (1977)                                            5.000000
# Empire Strikes Back, The (1980)                             5.000000
# Empire Strikes Back, The (1980)                             3.739907
# Star Wars (1977)                                            3.739907
# Return of the Jedi (1983)                                   3.606146
# Return of the Jedi (1983)                                   3.362779
# Raiders of the Lost Ark (1981)                              2.693297
# Raiders of the Lost Ark (1981)                              2.680586
# Adventures of Priscilla, Queen of the Desert, The (1994)    2.000000
# Austin Powers: International Man of Mystery (1997)          1.887164
# dtype: float64
# ...

# %%
''''
To merge duplicate entires present  in this variable produced by each film in myRatings 
as they were similar to more than one movies. this makes recommendation more strong
'''
simCandidates =simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace=True, ascending = False)
print(simCandidates.head(10))
# Out:
# Empire Strikes Back, The (1980)              8.899920
# Star Wars (1977)                             8.885404
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Cinderella (1950)                            3.245412
# Sting, The (1973)                            3.209627
# Wizard of Oz, The (1939)                     3.200268
# dtype: float64

# %% [markdown]
# #### Last thing is to filter out data that we already rated.

# %%
filteredsims=simCandidates.drop(myRatings.index)
#filteredsims=filteredsims/2  if you want to converts rating from 10 to 5 scale
filteredsims.head(10)
# Out:
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Cinderella (1950)                            3.245412
# Sting, The (1973)                            3.209627
# Wizard of Oz, The (1939)                     3.200268
# Field of Dreams (1989)                       3.068508
# E.T. the Extra-Terrestrial (1982)            2.972247
# dtype: float64

# %% [markdown]
# ### And there we have it
